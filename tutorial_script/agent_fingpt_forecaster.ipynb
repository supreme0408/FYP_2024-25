# %% [markdown]
# # FinGPT-Forecaster Re-implemented with FinRobot

# %% [markdown]
# In this demo, we set up an agent to emulate the behavior of model in the fingpt-forecaster project with AutoGen, which takes a company's ticker symbol, recent basic financials and market news as input and predict its stock movements.
#
# For detail of the original project, check out  [FinGPT-Forecaster](https://github.com/AI4Finance-Foundation/FinGPT/tree/master/fingpt/FinGPT_Forecaster)!  🔥[Demo](https://huggingface.co/spaces/FinGPT/FinGPT-Forecaster), [Medium Blog](https://medium.datadriveninvestor.com/introducing-fingpt-forecaster-the-future-of-robo-advisory-services-50add34e3d3c) & [Model](https://huggingface.co/FinGPT/fingpt-forecaster_dow30_llama2-7b_lora) on Huggingface🤗!
#
# This is a default bot, for more configurable demo, see [advanced tutorial](../tutorials_advanced/agent_fingpt_forecaster.ipynb)

# %%
import autogen
import sys
import os

sys.path.append(os.path.abspath(".."))  # Add the parent directory
from finrobot.utils import get_current_date, register_keys_from_json
from finrobot.agents.workflow import SingleAssistant

# %% [markdown]
# After importing all the necessary packages and functions, we instantiate a SingleAssistant workflow "Market_Analyst".
# We also need the config for OpenAI & Finnhub here.
# - for openai configuration, rename OAI_CONFIG_LIST_sample to OAI_CONFIG_LIST and replace the api keys
# - for finnhub configuration, rename config_api_keys_sample to config_api_keys and replace the api keys

# %%
# Read OpenAI API keys from a JSON file
llm_config = {
    "config_list": autogen.config_list_from_json(
        "../OAI_CONFIG_LIST",
        filter_dict={"model": ["llama-3.3-70b-versatile"]},
    ),
    "timeout": 120,
    "temperature": 0,
}

# Register FINNHUB API keys
register_keys_from_json("../config_api_keys")

# %% [markdown]
# Define the assistant, and simply start chatting!

# %%
company = "SALESFORCE"

assitant = SingleAssistant(
    "Market_Analyst",
    llm_config,
    # set to "ALWAYS" if you want to chat instead of simply receiving the prediciton
    human_input_mode="NEVER",
)
assitant.chat(
    f"Use all the tools provided to retrieve information available for {company} upon {get_current_date()}. Analyze the positive developments and potential concerns of {company} "
    "with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. "
    f"Then make a rough prediction (e.g. up/down by 2-3%) of the {company} stock price movement for next week. Provide a summary analysis to support your prediction."
)
# Out:
# User_Proxy (to Market_Analyst):
#
# Use all the tools provided to retrieve information available for SALESFORCE upon 2025-03-04. Analyze the positive developments and potential concerns of SALESFORCE with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. Then make a rough prediction (e.g. up/down by 2-3%) of the SALESFORCE stock price movement for next week. Provide a summary analysis to support your prediction.
#
# --------------------------------------------------------------------------------
# Market_Analyst (to User_Proxy):
#
# ***** Suggested tool call (call_j4g8): get_company_profile *****
# Arguments:
# {"symbol": "CRM"}
# ****************************************************************
# ***** Suggested tool call (call_ct99): get_company_news *****
# Arguments:
# {"symbol": "CRM", "start_date": "2024-01-01", "end_date": "2025-03-04"}
# D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\oai\groq.py:279: UserWarning: Cost calculation not available for model llama-3.3-70b-versatile
#   warnings.warn(f"Cost calculation not available for model {model}", UserWarning)
# *************************************************************
# ***** Suggested tool call (call_n8yw): get_basic_financials *****
# Arguments:
# {"symbol": "CRM"}
# *****************************************************************
# ***** Suggested tool call (call_wdmd): get_stock_data *****
# Arguments:
# {"symbol": "CRM", "start_date": "2024-01-01", "end_date": "2025-03-04"}
# ***********************************************************
#
# --------------------------------------------------------------------------------
#
# >>>>>>>> EXECUTING FUNCTION get_company_profile...
# Call ID: call_j4g8
# Input arguments: {'symbol': 'CRM'}
# Finnhub client initialized
#
# >>>>>>>> EXECUTING FUNCTION get_company_news...
# Call ID: call_ct99
# Input arguments: {'symbol': 'CRM', 'start_date': '2024-01-01', 'end_date': '2025-03-04'}
# Finnhub client initialized
#
# >>>>>>>> EXECUTING FUNCTION get_basic_financials...
# Call ID: call_n8yw
# Input arguments: {'symbol': 'CRM'}
# Finnhub client initialized
#
# >>>>>>>> EXECUTING FUNCTION get_stock_data...
# Call ID: call_wdmd
# Input arguments: {'symbol': 'CRM', 'start_date': '2024-01-01', 'end_date': '2025-03-04'}
# User_Proxy (to Market_Analyst):
#
# ***** Response from calling tool (call_j4g8) *****
# [Company Introduction]:
#
# Salesforce Inc is a leading entity in the Technology sector. Incorporated and publicly traded since 2004-06-23, the company has established its reputation as one of the key players in the market. As of today, Salesforce Inc has a market capitalization of 280458.43 in USD, with 957.00 shares outstanding.
#
# Salesforce Inc operates primarily in the US, trading under the ticker CRM on the NEW YORK STOCK EXCHANGE, INC.. As a dominant force in the Technology space, the company continues to innovate and drive progress within the industry.
# **************************************************
#
# --------------------------------------------------------------------------------
# ***** Response from calling tool (call_ct99) *****
#              date                                                                      headline                                                                                                                                                                                                                                                                                                                              summary
# 0  20250103163000               Should You Forget Palantir and Buy These 2 Tech Stocks Instead?  Palantir Technologies (NASDAQ: PLTR) was the best-performing stock in the S&P 500 last year.  It continues to have a big opportunity as it starts transitioning customers from proof of concept into production.  Let's look at two other stocks benefiting from AI trading at much cheaper valuations that investors can consider.
# 1  20250107181500      Dow down 113 points on losses in shares of NVIDIA Corp., Amazon.com Inc.                                                                                                                                                                                                                                                             Dow down 113 points on losses in shares of NVIDIA Corp., Amazon.com Inc.
# 2  20250107200300                                   Financial Advisors, Get Ready for AI Agents                                                                                                                                                                                                                                                                                          Financial Advisors, Get Ready for AI Agents
# 3  20250108171308     Agents of Change: How Businesses are Winning with Salesforce’s Agentforce                                                                                                                           Artificial Intelligence Agents of Change: How Businesses are Winning with Salesforce's Agentforce January 8, 2025 3 min read Companies worldwide are jumping into AI - and for service organizations in...
# 4  20250108171913    Salesforce: There Are Much Better AI Stocks Out There (Technical Analysis)
# 5  20250114120300                                           The Ithaka Group Q4 2024 Commentary                                                                                                                                                                 During the fourth quarter Ithakaâs portfolio performance bested the R1000G by 133bps, 8.4% to 7.1% (gross of fees), in a relatively narrow market. Read more here.
# 6  20250131112325  Anrok Announces Anrok for Salesforce Revenue Cloud on Salesforce AppExchange                                                                                                                           SAN FRANCISCO - Anrok today announced it has launched Anrok for Salesforce Revenue Cloud on Salesforce AppExchange, a leading enterprise marketplace for partner apps and experts, empowering customers...
# 7  20250204164700   Palantir Shows the AI Trade Is Alive and Well. 2 Stocks That Could Benefit.                                                                                                                                                                                                                                                          Palantir Shows the AI Trade Is Alive and Well. 2 Stocks That Could Benefit.
# 2025-02-06 00:00:00-05:00  337.480011  337.480011  329.100006  330.809998  13240600        0.0           0.0
# 2025-02-07 00:00:00-05:00  332.000000  333.820007  323.720001  325.829987   7626100        0.0           0.0
# 2025-02-10 00:00:00-05:00  327.920013  331.750000  326.649994  327.200012   5981900        0.0           0.0
# 2025-02-11 00:00:00-05:00  324.019989  326.440002  321.260010  324.399994   5455900        0.0           0.0
# 2025-02-12 00:00:00-05:00  319.549988  327.000000  316.970001  326.119995   5643400        0.0           0.0
# 2025-02-13 00:00:00-05:00  326.200012  330.350006  323.220001  329.850006   4312100        0.0           0.0
# 2025-02-14 00:00:00-05:00  328.029999  328.500000  322.619995  326.540009   5879700        0.0           0.0
# 2025-02-18 00:00:00-05:00  328.589996  329.160004  323.000000  328.959991   5262100        0.0           0.0
# 2025-02-19 00:00:00-05:00  329.739990  329.739990  322.869995  324.529999   5012000        0.0           0.0
# 2025-02-20 00:00:00-05:00  322.239990  324.450012  318.209991  318.429993   6393100        0.0           0.0
# 2025-02-21 00:00:00-05:00  318.970001  318.970001  306.859985  309.799988   7353200        0.0           0.0
# 2025-02-24 00:00:00-05:00  311.510010  312.730011  303.519989  308.320007   6652900        0.0           0.0
# 2025-02-25 00:00:00-05:00  306.250000  308.420013  300.619995  305.880005   7360100        0.0           0.0
# 2025-02-26 00:00:00-05:00  312.660004  313.700012  306.450012  307.329987  12638500        0.0           0.0
# 2025-02-27 00:00:00-05:00  296.339996  304.920013  292.670013  294.899994  16691400        0.0           0.0
# 2025-02-28 00:00:00-05:00  295.959991  301.980011  292.149994  297.850006  10863100        0.0           0.0
# 2025-03-03 00:00:00-05:00  301.000000  303.070007  291.059998  293.059998   6293200        0.0           0.0
# **************************************************
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[5], line 9
#       1 company = "SALESFORCE"
#       3 assitant = SingleAssistant(
#       4     "Market_Analyst",
#       5     llm_config,
#       6     # set to "ALWAYS" if you want to chat instead of simply receiving the prediciton
#       7     human_input_mode="NEVER",
#       8 )
# ----> 9 assitant.chat(
#      10     f"Use all the tools provided to retrieve information available for {company} upon {get_current_date()}. Analyze the positive developments and potential concerns of {company} "
#      11     "with 2-4 most important factors respectively and keep them concise. Most factors should be inferred from company related news. "
#      12     f"Then make a rough prediction (e.g. up/down by 2-3%) of the {company} stock price movement for next week. Provide a summary analysis to support your prediction."
#      13 )
#
# File D:\My\FinRobot\finrobot\agents\workflow.py:154, in SingleAssistant.chat(self, message, use_cache, **kwargs)
#     152 def chat(self, message: str, use_cache=False, **kwargs):
#     153     with Cache.disk() as cache:
# --> 154         self.user_proxy.initiate_chat(
#     155             self.assistant,
#     156             message=message,
#     157             cache=cache if use_cache else None,
#     158             **kwargs,
#     159         )
#     161     print("Current chat finished. Resetting agents ...")
#     162     self.reset()
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1499, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1497     else:
#    1498         msg2send = self.generate_init_message(message, **kwargs)
# -> 1499     self.send(msg2send, recipient, silent=silent)
#    1500 summary = self._summarize_chat(
#    1501     summary_method,
#    1502     summary_args,
#    1503     recipient,
#    1504     cache=cache,
#    1505 )
#    1506 for agent in [self, recipient]:
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1191, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1189 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1190 if valid:
# -> 1191     recipient.receive(message, self, request_reply, silent)
#    1192 else:
#    1193     raise ValueError(
#    1194         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1195     )
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1301, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1299 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1300 if reply is not None:
# -> 1301     self.send(reply, sender, silent=silent)
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1191, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1189 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1190 if valid:
# -> 1191     recipient.receive(message, self, request_reply, silent)
#    1192 else:
#    1193     raise ValueError(
#    1194         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1195     )
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1301, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1299 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1300 if reply is not None:
# -> 1301     self.send(reply, sender, silent=silent)
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1191, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1189 valid = self._append_oai_message(message, "assistant", recipient, is_sending=True)
#    1190 if valid:
# -> 1191     recipient.receive(message, self, request_reply, silent)
#    1192 else:
#    1193     raise ValueError(
#    1194         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1195     )
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1299, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1297 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1298     return
# -> 1299 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1300 if reply is not None:
#    1301     self.send(reply, sender, silent=silent)
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:2437, in ConversableAgent.generate_reply(self, messages, sender, **kwargs)
#    2435     continue
#    2436 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 2437     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    2438     if logging_enabled():
#    2439         log_event(
#    2440             self,
#    2441             "reply_func_executed",
#    (...)
#    2445             reply=reply,
#    2446         )
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1817, in ConversableAgent.generate_oai_reply(self, messages, sender, config)
#    1815 if messages is None:
#    1816     messages = self._oai_messages[sender]
# -> 1817 extracted_response = self._generate_oai_reply_from_client(
#    1818     client, self._oai_system_message + messages, self.client_cache
#    1819 )
#    1820 return (False, None) if extracted_response is None else (True, extracted_response)
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\agentchat\conversable_agent.py:1836, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache)
#    1833         all_messages.append(message)
#    1835 # TODO: #1143 handle token limit exceeded error
# -> 1836 response = llm_client.create(
#    1837     context=messages[-1].pop("context", None),
#    1838     messages=all_messages,
#    1839     cache=cache,
#    1840     agent=self,
#    1841 )
#    1842 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    1844 if extracted_response is None:
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\oai\client.py:1119, in OpenAIWrapper.create(self, **config)
#    1117 try:
#    1118     request_ts = get_current_ts()
# -> 1119     response = client.create(params)
#    1120 except Exception as e:
#    1121     if openai_result.is_successful:
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\autogen\oai\groq.py:161, in GroqClient.create(self, params)
#     158 streaming_tool_calls = []
#     160 ans = None
# --> 161 response = client.chat.completions.create(**groq_params)
#     162 if groq_params["stream"]:
#     163     # Read in the chunks as they stream, taking in tool_calls which may be across
#     164     # multiple chunks if more than one suggested
#     165     ans = ""
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\groq\resources\chat\completions.py:322, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, n, parallel_tool_calls, presence_penalty, reasoning_format, response_format, seed, service_tier, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     166 def create(
#     167     self,
#     168     *,
#    (...)
#     198     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     199 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     200     """
#     201     Creates a model response for the given chat conversation.
#     202
#    (...)
#     320       timeout: Override the client-level default timeout for this request, in seconds
#     321     """
# --> 322     return self._post(
#     323         "/openai/v1/chat/completions",
#     324         body=maybe_transform(
#     325             {
#     326                 "messages": messages,
#     327                 "model": model,
#     328                 "frequency_penalty": frequency_penalty,
#     329                 "function_call": function_call,
#     330                 "functions": functions,
#     331                 "logit_bias": logit_bias,
#     332                 "logprobs": logprobs,
#     333                 "max_completion_tokens": max_completion_tokens,
#     334                 "max_tokens": max_tokens,
#     335                 "n": n,
#     336                 "parallel_tool_calls": parallel_tool_calls,
#     337                 "presence_penalty": presence_penalty,
#     338                 "reasoning_format": reasoning_format,
#     339                 "response_format": response_format,
#     340                 "seed": seed,
#     341                 "service_tier": service_tier,
#     342                 "stop": stop,
#     343                 "stream": stream,
#     344                 "temperature": temperature,
#     345                 "tool_choice": tool_choice,
#     346                 "tools": tools,
#     347                 "top_logprobs": top_logprobs,
#     348                 "top_p": top_p,
#     349                 "user": user,
#     350             },
#     351             completion_create_params.CompletionCreateParams,
#     352         ),
#     353         options=make_request_options(
#     354             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     355         ),
#     356         cast_to=ChatCompletion,
#     357         stream=stream or False,
#     358         stream_cls=Stream[ChatCompletionChunk],
#     359     )
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\groq\_base_client.py:1266, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1252 def post(
#    1253     self,
#    1254     path: str,
#    (...)
#    1261     stream_cls: type[_StreamT] | None = None,
#    1262 ) -> ResponseT | _StreamT:
#    1263     opts = FinalRequestOptions.construct(
#    1264         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1265     )
# -> 1266     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\groq\_base_client.py:958, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     955 else:
#     956     retries_taken = 0
# --> 958 return self._request(
#     959     cast_to=cast_to,
#     960     options=options,
#     961     stream=stream,
#     962     stream_cls=stream_cls,
#     963     retries_taken=retries_taken,
#     964 )
#
# File D:\Anaconda3\envs\finrobot\lib\site-packages\groq\_base_client.py:1061, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1058         err.response.read()
#    1060     log.debug("Re-raising status error")
# -> 1061     raise self._make_status_error_from_response(err.response) from None
#    1063 return self._process_response(
#    1064     cast_to=cast_to,
#    1065     options=options,
#    (...)
#    1069     retries_taken=retries_taken,
#    1070 )
#
# APIStatusError: Error code: 413 - {'error': {'message': 'Request too large for model `llama-3.3-70b-versatile` in organization `org_01jfvjt0hsebg9eppa93ha6je6` service tier `on_demand` on tokens per minute (TPM): Limit 6000, Requested 9534, please reduce your message size and try again. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
